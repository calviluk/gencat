# %%
from ase.io import read, write

# %%
target_elements = ["Sc", "Ti", "V", "Cr", "Mn", "Fe", "Co", "Ni", "Cu", "Zn","Y",
     "Zr", "Nb", "Mo", "Ru", "Rh", "Pd", "Ag", "Cd", "Hf", "Ta", "W", "Re", "Os", "Ir", "Pt", "Au", "Hg",
      "Al", "Ga", "In"]
print(len(target_elements))
# Out:
# 31

# %%
all_structures = read('C:/Users/lucas/Desktop/DTU/Fall 2025/ML for Materials/Group work code/Relaxed structures/Total relaxed job/relaxed_structures.extxyz', index=':')
filtered_structures = [
    atoms for atoms in all_structures if set(atoms.get_chemical_symbols()).issubset(target_elements)
]

# %%
print (len(filtered_structures))
# Out:
# 7569
